# %%
import pandas as pd
import os
from matplotlib import pyplot as plt
import seaborn as sns

# %%
MovieGross = pd.read_csv("C:\\Users\\697299\\Documents\\Jignesh\\Data Analysis\\Python\\Udemy_Python_SDS_AtoZ\\MovieGross_Corrected.csv")

# %%
MovieGross
# Out:
#     Day of Week                                Director   Genre  \
# 0        Friday                               Brad Bird  action
# 1        Friday                             Scott Waugh  action
# 2        Friday                          Patrick Hughes  action
# 3        Friday                 Phil Lord, Chris Miller  comedy
# 4        Friday                         Roland Emmerich  action
# ..          ...                                     ...     ...
# 603   Wednesday                        William Friedkin  horror
# 604   Wednesday                            George Lucas  action
# 605      Friday                           James Cameron  sci-fi
# 606   Wednesday                           James Cameron   drama
# 607      Friday  George Cukor, Victor Fleming, Sam Wood   drama
#
#             Movie Title Release Date               Studio  \
# 0          Tomorrowland   22/05/2015  Buena Vista Studios
# 1        Need for Speed   14/03/2014  Buena Vista Studios
# ...

# %%
MovieGross.head()
# Out:
#   Day of Week                 Director   Genre        Movie Title  \
# 0      Friday                Brad Bird  action       Tomorrowland
# 1      Friday              Scott Waugh  action     Need for Speed
# 2      Friday           Patrick Hughes  action  The Expendables 3
# 3      Friday  Phil Lord, Chris Miller  comedy     21 Jump Street
# 4      Friday          Roland Emmerich  action   White House Down
#
#   Release Date               Studio Adjusted Gross ($mill)  Budget ($mill)  \
# 0   22/05/2015  Buena Vista Studios                  202.1           170.0
# 1   14/03/2014  Buena Vista Studios                  204.2            66.0
# 2   15/08/2014            Lionsgate                  207.1           100.0
# 3   16/03/2012                 Sony                  208.8            42.0
# 4   28/06/2013                 Sony                  209.7           150.0
#
#   Gross ($mill)  IMDb Rating  MovieLens Rating Overseas ($mill)  Overseas%  \
# ...

# %%
MovieGross.columns
# Out:
# Index(['Day of Week', 'Director', 'Genre', 'Movie Title', 'Release Date',
#        'Studio', 'Adjusted Gross ($mill)', 'Budget ($mill)', 'Gross ($mill)',
#        'IMDb Rating', 'MovieLens Rating', 'Overseas ($mill)', 'Overseas%',
#        'Profit ($mill)', 'Profit%', 'Runtime (min)', 'US ($mill)',
#        'Gross % US'],
#       dtype='object')

# %%
MovieGross.columns = ['DayofWeek', 'Director', 'Genre', 'MovieTitle', 'ReleaseDate',
       'Studio', 'AdjustedGross', 'Budget', 'TotalGross',
       'IMDbRating', 'MovieLensRating', 'OverseasGross', 'OverseasPercent',
       'Profit', 'ProfitPercent', 'Runtime', 'USGross',
       'USPercent']

# %%
MovieGross.head()
# Out:
#   DayofWeek                 Director   Genre         MovieTitle ReleaseDate  \
# 0    Friday                Brad Bird  action       Tomorrowland  22/05/2015
# 1    Friday              Scott Waugh  action     Need for Speed  14/03/2014
# 2    Friday           Patrick Hughes  action  The Expendables 3  15/08/2014
# 3    Friday  Phil Lord, Chris Miller  comedy     21 Jump Street  16/03/2012
# 4    Friday          Roland Emmerich  action   White House Down  28/06/2013
#
#                 Studio AdjustedGross  Budget TotalGross  IMDbRating  \
# 0  Buena Vista Studios         202.1   170.0      202.1         6.7
# 1  Buena Vista Studios         204.2    66.0      203.3         6.6
# 2            Lionsgate         207.1   100.0      206.2         6.1
# 3                 Sony         208.8    42.0      201.6         7.2
# 4                 Sony         209.7   150.0      205.4         8.0
#
#    MovieLensRating OverseasGross  OverseasPercent Profit  ProfitPercent  \
# ...

# %%
sns.boxplot(data=MovieGross[MovieGross[Genre == 'action']], x='Genre', y='USPercent')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-7cb1e228979d> in <module>
# ----> 1 sns.boxplot(data=MovieGross[MovieGross[Genre == 'action']], x='Genre', y='USPercent')
#
# NameError: name 'Genre' is not defined

# %%
MovieGenre = MovieGross[(MovieGross.Genre == 'action') | (MovieGross.Genre == 'comedy') |(MovieGross.Genre == 'adventure') | \
           (MovieGross.Genre == 'animation') | (MovieGross.Genre=='drama')]

#MovieGross.Genre.unique()
MovieGross.Studio.unique()
# Filter the dataframe by studio
mov3 = MovieGenre[(MovieGross.Studio == 'Buena Vista Studios') | (MovieGross.Studio == 'Fox') | (MovieGross.Studio== 'Paramount Pictures') \
                  | (MovieGross.Studio == 'Sony') | (MovieGross.Studio == 'Universal') | (MovieGross.Studio == 'WB')]

mov3
# Out:
# <ipython-input-45-4821d2d3dde9>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   mov3 = MovieGenre[(MovieGross.Studio == 'Buena Vista Studios') | (MovieGross.Studio == 'Fox') | (MovieGross.Studio== 'Paramount Pictures') \
#      DayofWeek                 Director      Genre  \
# 0       Friday                Brad Bird     action
# 1       Friday              Scott Waugh     action
# 3       Friday  Phil Lord, Chris Miller     comedy
# 4       Friday          Roland Emmerich     action
# 5       Friday               David Ayer     action
# ..         ...                      ...        ...
# 598     Friday         Steven Spielberg  adventure
# 600     Friday         Steven Spielberg  adventure
# 602    Tuesday        Richard Fleischer  adventure
# 604  Wednesday             George Lucas     action
# 606  Wednesday            James Cameron      drama
#
#                       MovieTitle ReleaseDate               Studio  \
# ...

# %%
#This dont work
#sns.boxplot(data=mov3, x='Genre', y='USPercent', hue='Studio')

# Plot the boxsplots
ax = sns.boxplot(data=mov3, x='Genre', y='USPercent', orient='v', color='lightgray', showfliers=False)
#plt.setp(ax.artists, alpha=0.5)

# Add in points to show each observation
sns.stripplot(data=mov3, x='Genre', y='USPercent', jitter=True, size=6, linewidth=0, hue = 'Studio', alpha=0.7)

ax.axes.set_title('Domestic Gross % by Genre',fontsize=30)
ax.set_xlabel('Genre',fontsize=20)
ax.set_ylabel('US % Gross',fontsize=20)

# Define where to place the legend
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
